# %%
import pandas as pd

# %%
dataset = pd.read_csv("Kideny_ds_Cleaned.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0  id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0           0   0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent
# 1           1   1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent
# 2           2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3           3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4           4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
#
#    ... pcv    wc   rc  htn   dm  cad  appet   pe  ane classification
# 0  ...  44  7800  5.2  yes  yes   no   good   no   no            ckd
# 1  ...  38  6000  4.7   no   no   no   good   no   no            ckd
# 2  ...  31  7500  4.7   no  yes   no   poor   no  yes            ckd
# 3  ...  32  6700  3.9  yes   no   no   poor  yes  yes            ckd
# 4  ...  35  7300  4.6   no   no   no   good   no   no            ckd
#
# [5 rows x 27 columns]

# %%
X = dataset.values[:,0:25]

# Extracting target/ class labels
y = dataset.values[:,26]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 47, test_size = 0.25)

# %%
from sklearn.tree import DecisionTreeClassifier
DTree = DecisionTreeClassifier(criterion = 'entropy')
DTree.fit(X_train, y_train)
y_pred =  DTree.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1278/1778957220.py in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 DTree = DecisionTreeClassifier(criterion = 'entropy')
# ----> 3 DTree.fit(X_train, y_train)
#       4 y_pred =  DTree.predict(X_test)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~/.conda/envs/default/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# ~/.conda/envs/default/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# ~/.conda/envs/default/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ValueError: could not convert string to float: 'normal'
